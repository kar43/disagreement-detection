# %%
# %tensorflow_version 2.x
import tensorflow as tf
print(tf.__version__)
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# 2.15.0

# %%
# All general imports
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelBinarizer

import keras
# !pip install keras_preprocessing
from keras_preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
from keras.layers import Input, Embedding, Reshape, Conv2D, MaxPool2D, Concatenate, Flatten, Dropout, Dense, Bidirectional, GlobalAveragePooling1D, GRU, GlobalMaxPooling1D, concatenate
from keras.optimizers import Adam
from keras.layers import LSTM, GRU, Conv1D, MaxPool1D, Activation, Add

from keras.models import Model, Sequential
from keras.layers import SpatialDropout1D

from keras.layers import Layer, Dense, Input, Embedding, Dropout, Activation, Conv2D, MaxPooling2D, AveragePooling2D, Softmax
from keras import initializers, regularizers, constraints, optimizers, layers
from keras import backend as K

from keras.callbacks import EarlyStopping

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, accuracy_score
import io, os, gc
# Out:
# Requirement already satisfied: keras_preprocessing in /usr/local/lib/python3.10/dist-packages (1.1.2)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras_preprocessing) (1.25.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from keras_preprocessing) (1.16.0)

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

#tf.debugging.set_log_device_placement(True)
# Out:
# Num GPUs Available:  1

# %%
# Loading drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Setting the working directory
# !ls
# %cd drive/MyDrive/Project
# !pwd
# Out:
# drive  sample_data
# /content/drive/MyDrive/Project
# /content/drive/MyDrive/Project

# %%
#################### Importing FNC Datasets ####################

le = LabelEncoder()
le2 = LabelEncoder()

# Train set
train_df = pd.read_csv('data/train_fnc_with_labels_2nd.csv')
print(train_df.columns)
train_df['Stance'] = le.fit_transform(train_df['Stance']) # agree = 0, disagree = 1
train_df['single_new_emo'] = le2.fit_transform(train_df['single_new_emo']) # emotions agree = 0, disagree = 1
train_df.head()

# Test set
test_df = pd.read_csv('data/test_fnc_with_labels.csv')
print(test_df.columns)
test_df['Stance'] = le.transform(test_df['Stance'])
test_df['single_new_emo'] = le2.transform(test_df['single_new_emo'])
test_df.head()
# Out:
# Index(['id', 'Body', 'Headline', 'Stance', 'Emotion_Labels', 'Novelty_Quora',
#        'com_femotion', 'single_new_emo', 'premise_emo', 'hypothesis_emo',
#        'novelty_label'],
#       dtype='object')
# Index(['id', 'Body', 'Headline', 'Stance', 'Emotion_Labels', 'Novelty_Quora',
#        'com_femotion', 'single_new_emo', 'premise_emo', 'hypothesis_emo',
#        'novelty_label'],
#       dtype='object')
#      id                                               Body  \
# 0  1964  Last week, Apple sent out the invites for its ...
# 1  1618  Did a woman claiming to have a third breast pl...
# 2  2316  A fourth grader named Aiden Steward was suspen...
# 3  1452  LOS ANGELES (CBS Seattle/AP) — A scorpion stun...
# 4  1636  If the bizarre story about Joan Rivers' doctor...
#
#                                             Headline  Stance  Emotion_Labels  \
# 0  EXCLUSIVE: Apple To Unveil The Long-Awaited Re...       0               1
# 1                              3-Boobed Woman a Fake       0               0
# 2  Texas Boy Suspended For 'Threatening' Classmat...       0               0
# 3  Woman stung by scorpion on Alaska Airlines flight       0               0
# 4  Disgusting! Joan Rivers Doc Gwen Korovin’s Sic...       1               0
#
#    Novelty_Quora  com_femotion  single_new_emo  premise_emo  hypothesis_emo  \
# 0              1             1               1            1               0
# 1              0             0               0            1               1
# 2              1             1               1            1               0
# 3              0             0               0            1               1
# 4              1             0               0            1               1
#
#    novelty_label
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
# Importing BERT embeddings
pre_bert_fnc = np.load("bert/pre_bert_fnc.npy")
hyp_bert_fnc = np.load("bert/hyp_bert_fnc.npy")
print('Premise', pre_bert_fnc.shape)
print('Hypothesis', hyp_bert_fnc.shape)
# Out:
# Premise (3615, 768)
# Hypothesis (3615, 768)

# %%
pre_bert_fnc_test = np.load("bert/pre_bert_test_fnc.npy")
hyp_bert_fnc_test = np.load("bert/hyp_bert_test_fnc.npy")
print('Premise', pre_bert_fnc_test.shape)
print('Hypothesis', hyp_bert_fnc_test.shape)
# Out:
# Premise (2600, 768)
# Hypothesis (2600, 768)

# %%
# Importing auxiliary features
pre_features_fnc = np.load("new_features/pre_features_train_fnc.npy")
hyp_features_fnc = np.load("new_features/hyp_features_train_fnc.npy")
print('Premise', pre_features_fnc.shape)
print('Hypothesis', hyp_features_fnc.shape)
# Out:
# Premise (3615, 16)
# Hypothesis (3615, 16)

# %%
pre_features_fnc_test = np.load("new_features/pre_features_test_fnc.npy")
hyp_features_fnc_test = np.load("new_features/hyp_features_test_fnc.npy")
print('Premise', pre_features_fnc_test.shape)
print('Hypothesis', hyp_features_fnc_test.shape)
# Out:
# Premise (2600, 16)
# Hypothesis (2600, 16)

# %%
train_lst_1 = train_df['Body'].tolist()
train_lst_2 = train_df['Headline'].tolist()
print('Train Headline: ', len(train_lst_2))
uq_tr_1 = list(set(train_lst_1))
uq_tr_2 = list(set(train_lst_2))
train_merged = uq_tr_1 + uq_tr_2
print('Train length is', len(train_merged))

test_lst_1 = test_df['Body'].tolist()
test_lst_2 = test_df['Headline'].tolist()
uq_ts_1 = list(set(test_lst_1))
uq_ts_2 = list(set(test_lst_2))
test_merged = uq_ts_1 + uq_ts_2
print('Test length is', len(test_merged))

total_dataset = train_merged + test_merged
print('Total dataset length is', len(total_dataset))
# Out:
# Train Headline:  3615
# Train length is 1735
# Test length is 961
# Total dataset length is 2696

# %%
train_max_1 = max([len(s) for s in train_lst_1])
train_max_2 = max([len(s) for s in train_lst_2])
train_avg_1 = int(np.average([len(s) for s in train_lst_1]))
train_avg_2 = int(np.average([len(s) for s in train_lst_2]))
train_min_1 = min([len(s) for s in train_lst_1])
train_min_2 = min([len(s) for s in train_lst_2])
print("Train set: ")
print('Body -> Max: ', train_max_1, 'Avg: ', train_avg_1, 'Min: ', train_min_1)
print('Headline -> Max: ', train_max_2, 'Avg: ', train_avg_2, 'Min: ', train_min_2)
test_max_1 = max([len(s) for s in test_lst_1])
test_max_2 = max([len(s) for s in test_lst_2])
test_avg_1 = int(np.average([len(s) for s in test_lst_1]))
test_avg_2 = int(np.average([len(s) for s in test_lst_2]))
test_min_1 = min([len(s) for s in test_lst_1])
test_min_2 = min([len(s) for s in test_lst_2])
print("Test set: ")
print('Body -> Max: ', test_max_1, 'Avg: ', test_avg_1, 'Min: ', test_min_1)
print('Headline -> Max: ', test_max_2, 'Avg: ', test_avg_2, 'Min: ', test_min_2)

MAX_LENGTH = 100
# Out:
# Train set:
# Body -> Max:  13580 Avg:  2093 Min:  38
# Headline -> Max:  215 Avg:  68 Min:  11
# Test set:
# Body -> Max:  19815 Avg:  2336 Min:  29
# Headline -> Max:  186 Avg:  69 Min:  10

# %%
import string
# !pip install nltk
import nltk
from nltk.tokenize import  word_tokenize

contr_dict = {"I\'m": "I am",
            "won\'t": "will not",
            "\'s" : "",
            "\'ll":"will",
            "\'ve":"have",
            "n\'t":"not",
            "\'re": "are",
            "\'d": "would",
            "y'all": "all of you",
            "\' " : " ",
            " \'" : " "}

known_typos = {
    "accordin ":"according ",
    "entirel ":"entirely ",
    "electri ":"electric"
}

def encode_char(text):
    text = text.replace(u"\u201d",'"') # replace unicode quotation
    text = text.replace(u"\u201c",'"')
    text = text.replace(u"\u2018","'")
    text = text.replace(u"\u2019","'")
    if u"\u201d" in text or u"\u201c" in text or u"\u2018" in text or u"\u2019" in text:
      print(text)
    encoded_string = text.encode("ascii", "ignore")
    text = encoded_string.decode()
    return text

def correct_typos(text):
    text = text + " "
    for typo in known_typos:
      text = text.replace(typo, " "+known_typos[typo])
    return text

def remove_html(text):
    text = text.replace("< i >", "")
    text = text.replace("< / i >", "")
    return text

def remove_numbers(text):
    no_digits = ""
    for i in text:
        if not i.isdigit():
            no_digits += i
    return no_digits

def remove_punctuation(text):
    punctuationfree = ""
    for i in range(len(text)):
      if text[i] not in string.punctuation:
        punctuationfree += text[i]
      else:
        if i < (len(text)-1) and text[i+1] != " ": # add space after punctuation
          punctuationfree += " "
    return punctuationfree

def tokenization(text):
    tokens = word_tokenize(text)
    return tokens

def remove_stopwords(stopwords, tokens):
    result = [t for t in tokens if t not in stopwords]
    return result

def tokens_to_text(tokens):
    result = " ".join(t for t in tokens)
    return result

# remove apostrophes and replaces contractions with full words
def replace_contractions(text, contr_dict=contr_dict):
    text = text.lower()
    for char in ["′","ʼ","`","՚","ʼ","ߴ","ߵ","＇", '“','”',"\'", "’", "‘"]:
      text = text.replace(char, "\'")
    for i in range(len(text)):
      if text[i] == "\'" and (i == 0 or text[i-1] == "."):
        text[i] == ""
    text = text.replace(" \'"," ")
    text = text.replace("\' "," ")
    for contr in contr_dict:
      text = text.replace(contr, " "+contr_dict[contr])
    text = text.replace("\'","")
    return text

def text_preprocessing(texts):
  new_texts = []
  for text in texts:
      text = encode_char(text)
      # text = remove_html(text)
      text = remove_numbers(text)
      text = replace_contractions(text)
      # text = remove_punctuation(text)
      text = correct_typos(text)
      # tokens =  tokenization(text)
      # stopwords = nltk.corpus.stopwords.words('english')
      # tokens = remove_stopwords(stopwords, tokens)
      # text = tokens_to_text(tokens)
      new_texts.append(text)
  return new_texts

total_dataset = text_preprocessing(total_dataset)
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
from nltk import tokenize
import nltk
nltk.download('punkt')

n_sent_lst = []
n_words_lst = []
for text in total_dataset: # count max number of sentences and max number of words in a sentence
  sentences = tokenize.sent_tokenize(text)
  n_sent_lst.append(len(sentences))
  n_words = 0
  for sent in sentences:
    n = len(tokenize.word_tokenize(sent))
    if n > n_words:
      n_words = n
  n_words_lst.append(n_words)

max_n_sent = max(n_sent_lst)
max_n_words = max(n_words_lst)

print(max_n_sent) # max num of sentences
print(max_n_words) # max num of words in a sentence

if max_n_sent > 10:
  m = 10
elif max_n_sent >= 5:
  m = max_n_sent
else:
  m = 5

if max_n_words > 50:
  n = 50
elif max_n_words >= 10:
  n = max_n_words
else:
  n = 10

#MAX_LENGTH = m*n
MAX_LENGTH = 150
print(MAX_LENGTH)

# %%
# Defining the tokenizer
def get_tokenizer(vocabulary_size):
  print('Training tokenizer...')
  tokenizer = Tokenizer(num_words= vocabulary_size)
  tweet_text = []
  print('Read {} Sentences'.format(len(total_dataset)))
  tokenizer.fit_on_texts(total_dataset)
  return tokenizer

# %%
def process_glove_line(line, dim):
    word = None
    embedding = None
    try:
      splitLine = line.split()
      word = " ".join(splitLine[:len(splitLine)-dim])
      embedding = np.array([float(val) for val in splitLine[-dim:]])
    except:
      print(line)
    return word, embedding

# For getting the embedding matrix
def get_embeddings():
  print('Generating embeddings matrix...')
  embeddings_file = 'glove.6B.300d.txt'
  embeddings_index = dict()
  with open(embeddings_file, 'r', encoding="utf-8") as infile:
    for line in infile:
      word, vector = process_glove_line(line, 300)
      embeddings_index[word] = vector
	# create a weight matrix for words in training docs
  vocabulary_size = len(embeddings_index)
  embeddinds_size = list(embeddings_index.values())[0].shape[0]
  print('Vocabulary = {}, embeddings = {}'.format(vocabulary_size, embeddinds_size))
  tokenizer = get_tokenizer(vocabulary_size)
  embedding_matrix = np.zeros((vocabulary_size, embeddinds_size))
  considered = 0
  total = len(tokenizer.word_index.items())
  oov = []
  for word, index in tokenizer.word_index.items():
    if index > vocabulary_size - 1:
      print(word, index)
      continue
    else:
      embedding_vector = embeddings_index.get(word)
      if embedding_vector is not None:
        embedding_matrix[index] = embedding_vector
        considered += 1
      else:
        oov.append(word)
  print('Considered ', considered, 'Left ', total - considered)
  return embedding_matrix, tokenizer, embeddings_index, oov

# %%
def get_data(tokenizer, MAX_LENGTH, input_df):
  print('Loading data')
  X1, X2, Y = [], [], []
  X1 = input_df['Body'].tolist()
  X2 = input_df['Headline'].tolist()
  X1 = text_preprocessing(X1)
  X2 = text_preprocessing(X2)
  Y_fnc = input_df['Stance'].tolist()
  Y_nv = input_df["novelty_label"].values
  Y_em = input_df["single_new_emo"].values
  # Y_nv = input_df["Novelty_Quora"].values
  # Y_em = input_df["com_femotion"].values
  assert len(X1) == len(X2) == len(Y_fnc) == len(Y_nv) == len(Y_em)
  sequences_1 = tokenizer.texts_to_sequences(X1)
  sequences_2 = tokenizer.texts_to_sequences(X2)
  X1 = pad_sequences(sequences_1, maxlen=MAX_LENGTH)
  X2 = pad_sequences(sequences_2, maxlen=MAX_LENGTH)
  Y_fnc = np.array(Y_fnc)
  Y_nv = np.array(Y_nv)
  Y_em = np.array(Y_em)
  return X1, X2, Y_fnc, Y_nv, Y_em

# %%
embedding_matrix, tokenizer, embeddings_index, oov = get_embeddings()
# Out:
# Generating embeddings matrix...
# Vocabulary = 400000, embeddings = 300
# Training tokenizer...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-242cfb94d451> in <cell line: 1>()
# ----> 1 embedding_matrix, tokenizer, embeddings_index, oov = get_embeddings()
#
# <ipython-input-7-ec437c1d1862> in get_embeddings()
#      23   embeddinds_size = list(embeddings_index.values())[0].shape[0]
#      24   print('Vocabulary = {}, embeddings = {}'.format(vocabulary_size, embeddinds_size))
# ---> 25   tokenizer = get_tokenizer(vocabulary_size)
#      26   embedding_matrix = np.zeros((vocabulary_size, embeddinds_size))
#      27   considered = 0
#
# <ipython-input-6-907aca89158e> in get_tokenizer(vocabulary_size)
#       4   tokenizer = Tokenizer(num_words= vocabulary_size)
#       5   tweet_text = []
# ----> 6   print('Read {} Sentences'.format(len(total_dataset)))
#       7   tokenizer.fit_on_texts(total_dataset)
#       8   return tokenizer
#
# NameError: name 'total_dataset' is not defined

# %%
def get_oov_freq(oov, total_dataset):
  oov_freq = dict()
  for s in total_dataset:
    for word in oov:
      count = s.count(word)
      if count > 0:
        try:
          oov_freq[word] += count
        except KeyError:
          oov_freq[word] = count
  return oov_freq

def show_oov_words(oov_freq, num_to_show=30):
    # Sort oov words by their frequency in the text
    sorted_oov = sorted(oov_freq.items(), key=lambda x:x[1], reverse=True)
    # Show oov words and their frequencies
    if (len(sorted_oov)>0):
        print("oov words:")
        for pair in sorted_oov[:num_to_show]:
          print("%s\t%s"%(pair[0], pair[1]))
    else:
        print("No words were out of vocabulary.")
    return len(sorted_oov)

# %%
# oov_freq = get_oov_freq(oov, total_dataset)
# oov_len = show_oov_words(oov_freq, 100)

# %%
# read ml data
X1, X2, Y_fnc, Y_nv, Y_em = get_data(tokenizer, MAX_LENGTH, train_df)
# Out:
# Loading data

# %%
#!pip install yellowbrick
from yellowbrick.target import ClassBalance
import matplotlib.pyplot as plt

print("Class balance for train data: ")
fig, ((ax1, ax2, ax3)) = plt.subplots(ncols=3, nrows=1, figsize=(10,3))

classes = le.inverse_transform(np.arange(2))
classes2 = le2.inverse_transform(np.arange(2))

visualiser_fnc = ClassBalance(labels=classes, ax=ax1)
visualiser_fnc.fit(Y_fnc)
visualiser_fnc.finalize()

visualiser_nv = ClassBalance(labels=['novel', 'duplicate'], ax=ax2) # 0 = novel, 1 = duplicate
visualiser_nv.fit(Y_nv)
visualiser_nv.finalize()

visualiser_em = ClassBalance(labels=classes2, ax=ax3) # 0 = agree, 1 = disagree
visualiser_em.fit(Y_em)
visualiser_em.finalize()
# Out:
# Class balance for train data:

# %%
print("FNC train data class balance: ")
unique, counts = np.unique(Y_fnc, return_counts=True)
dict(zip(unique, counts))
# Out:
# FNC train data class balance:
# {0: 2948, 1: 667}

# %%
X1_test, X2_test, Y_fnc_test, Y_nv_test, Y_em_test = get_data(tokenizer, MAX_LENGTH, test_df)
# Out:
# Loading data

# %%
print("Class distribution for test data: ")
fig, ((ax1, ax2, ax3)) = plt.subplots(ncols=3, nrows=1, figsize=(10,3))
classes = le.inverse_transform(np.arange(2))
classes2 = le2.inverse_transform(np.arange(2))

visualiser_fnc = ClassBalance(labels=classes, ax=ax1)
visualiser_fnc.fit(Y_fnc_test)
visualiser_fnc.finalize()

visualiser_nv = ClassBalance(labels=['novel', 'duplicate'], ax=ax2)
visualiser_nv.fit(Y_nv_test)
visualiser_nv.finalize()

visualiser_em = ClassBalance(labels=classes2, ax=ax3)
visualiser_em.fit(Y_em_test)
visualiser_em.finalize()
# Out:
# Class distribution for test data:

# %%
print("FNC test data class balance: ")
unique, counts = np.unique(Y_fnc_test, return_counts=True)
dict(zip(unique, counts))
# Out:
# FNC test data class balance:
# {0: 1903, 1: 697}

# %%
# Scaffold labels
novel = embeddings_index['original']
duplicate = embeddings_index['duplicate']
emotion_true = embeddings_index['anticipation']+embeddings_index['sadness']+embeddings_index['joy']+embeddings_index['trust']
emotion_false = embeddings_index['anger']+embeddings_index['fear']+embeddings_index['disgust']+embeddings_index['surprise']

# %%
# Novelty Bias
train_bias_nv = []
test_bias_nv = []
zero_vector = np.zeros((300,))

for i, row in train_df.iterrows():
    if row['novelty_label'] == 0:
        train_bias_nv.append(novel)
    elif row['novelty_label'] == 1:
        train_bias_nv.append(duplicate)
    else:
        train_bias_nv.append(zero_vector)

for i, row in test_df.iterrows():
    if row['novelty_label'] == 0:
        test_bias_nv.append(novel)
    elif row['novelty_label'] == 1:
        test_bias_nv.append(duplicate)
    else:
        test_bias_nv.append(zero_vector)

train_bias_nv = np.stack(train_bias_nv)
test_bias_nv = np.stack(test_bias_nv)
print('Train bias', train_bias_nv.shape)
print('Test bias', test_bias_nv.shape)
# Out:
# Train bias (3615, 300)
# Test bias (2600, 300)

# %%
# Emotion Bias
train_bias_em = []
test_bias_em = []
zero_vector = np.zeros((300,))

for i in range(len(train_df)):
    em_lab = train_df.loc[i, 'single_new_emo']
    if train_df.loc[i, 'Stance'] == 0 and em_lab == 0:
        train_bias_em.append(emotion_true)
    elif train_df.loc[i, 'Stance'] == 1 and em_lab == 1:
        train_bias_em.append(emotion_false)
    else:
        train_bias_em.append(zero_vector)

for i in range(len(test_df)):
    em_lab = train_df.loc[i, 'single_new_emo']
    if test_df.loc[i, 'Stance'] == 0 and em_lab == 0:
        test_bias_em.append(emotion_true)
    elif test_df.loc[i, 'Stance'] == 1 and em_lab == 1:
        test_bias_em.append(emotion_false)
    else:
        test_bias_em.append(zero_vector)

train_bias_em = np.stack(train_bias_em)
test_bias_em = np.stack(test_bias_em)
print('Train bias', train_bias_em.shape)
print('Test bias', test_bias_em.shape)
# Out:
# Train bias (3615, 300)
# Test bias (2600, 300)

# %%
# Considering the final train and test bias
train_bias = np.add(train_bias_nv, train_bias_em)
test_bias = np.add(test_bias_nv, test_bias_em)

# %%
# Creating one-hot encodings
y_train_nv = keras.utils.to_categorical(Y_nv)
# print(y_train_nv)
y_train_em = keras.utils.to_categorical(Y_em)
# print(y_train_em)
y_train_fnc = keras.utils.to_categorical(Y_fnc)
# print(y_train_fnc)
y_test_nv = keras.utils.to_categorical(Y_nv_test)
# print(y_test_nv)
y_test_em = keras.utils.to_categorical(Y_em_test)
# print(y_test_em)
y_test_fnc = keras.utils.to_categorical(Y_fnc_test)
# print(y_test_fnc)

# %%
from sklearn.model_selection import train_test_split
VALIDATION_RATIO = 0.1
RANDOM_STATE = 9527
x1_train, x1_val, \
x2_train, x2_val, \
x1_train_bert, x1_val_bert, \
x2_train_bert, x2_val_bert, \
x1_train_features, x1_val_features, \
x2_train_features, x2_val_features, \
y_train_nv, y_val_nv, \
y_train_em, y_val_em, \
y_train_fnc, y_val_fnc, \
train_bias, val_bias, \
train_bias_nv, val_bias_nv, \
train_bias_em, val_bias_em = \
    train_test_split(
        X1, X2,
        pre_bert_fnc, hyp_bert_fnc,
        pre_features_fnc, hyp_features_fnc,
        y_train_nv, y_train_em,
        y_train_fnc, train_bias,
        train_bias_nv, train_bias_em,
        test_size=VALIDATION_RATIO,
        random_state=RANDOM_STATE
)

# %%
print("Training Set")
print("-" * 10)
print(f"x1_train: {x1_train.shape}")
print(f"x2_train: {x2_train.shape}")
print(f"x1_train_bert : {x1_train_bert.shape}")
print(f"x2_train_bert : {x2_train_bert.shape}")
print(f"x1_train_features : {x1_train_features.shape}")
print(f"x2_train_features : {x2_train_features.shape}")
print(f"y_train_fnc : {y_train_fnc.shape}")
print(f"train_bias : {train_bias.shape}")

print("-" * 10)
print(f"x1_val:   {x1_val.shape}")
print(f"x2_val:   {x2_val.shape}")
print(f"x1_val_bert:   {x1_val_bert.shape}")
print(f"x2_val_bert :   {x2_val_bert.shape}")
print(f"x1_val_features:   {x1_val_features.shape}")
print(f"x2_val_features :   {x2_val_features.shape}")
print(f"y_val_fnc :   {y_val_fnc.shape}")
print(f"val_Bias : {val_bias.shape}")
print("-" * 10)
print("Test Set")
# Out:
# Training Set
# ----------
# x1_train: (3253, 150)
# x2_train: (3253, 150)
# x1_train_bert : (3253, 768)
# x2_train_bert : (3253, 768)
# x1_train_features : (3253, 16)
# x2_train_features : (3253, 16)
# y_train_fnc : (3253, 2)
# train_bias : (3253, 300)
# ----------
# x1_val:   (362, 150)
# x2_val:   (362, 150)
# x1_val_bert:   (362, 768)
# x2_val_bert :   (362, 768)
# x1_val_features:   (362, 16)
# x2_val_features :   (362, 16)
# y_val_fnc :   (362, 2)
# val_Bias : (362, 300)
# ----------
# Test Set

# %%
NUM_CLASSES = 2

MAX_SEQUENCE_LENGTH = MAX_LENGTH

NUM_LSTM_UNITS = 150

MAX_NUM_WORDS = embedding_matrix.shape[0]

NUM_EMBEDDING_DIM = embedding_matrix.shape[1]

# %%
class AttentionLayer(Layer):

    def __init__(self,attention_dim=300,return_coefficients=True,**kwargs):
        # Initializer
        self.supports_masking = True
        self.return_coefficients = return_coefficients
        self.init = initializers.get('glorot_uniform') # initializes values with uniform distribution
        self.attention_dim = attention_dim
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape): #(?,100,300)
        # Builds all weights
        # W = Weight matrix, b = bias vector, u = context vector
        assert len(input_shape) == 3
        self.W = K.variable(self.init((input_shape[-1], self.attention_dim)),name='W')
        self.b = K.variable(self.init((self.attention_dim, )),name='b')
        self.u = K.variable(self.init((self.attention_dim, 1)),name='u')
        self._trainable_weights = [self.W, self.b, self.u]

        super(AttentionLayer, self).build(input_shape)

    def call(self, hit, mask=None):
        # uit = annotations
        uit = K.bias_add(K.dot(hit, self.W),self.b)
        uit = K.tanh(uit)
        # ait = importance weights per word
        ait = K.dot(uit, self.u)
        ait = K.squeeze(ait, -1) # into 1D array
        ait = K.exp(ait)

        if mask is not None:
            ait *= K.cast(mask, K.floatx())

        ait /= K.cast(K.sum(ait, axis=1, keepdims=True) + K.epsilon(), K.floatx())
        ait = K.expand_dims(ait)
        weighted_input = hit * ait

        if self.return_coefficients:
            return [K.sum(weighted_input, axis=1), ait]
        else:
            return K.sum(weighted_input, axis=1)

# %%
## Bi-LSTMs

top_input_wd = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32', name='pre_input') # premise (glove)
bm_input_wd = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype='int32', name='hyp_input') # hypothesis (glove)

top_input_bt = Input(shape=(768, ), dtype='float32', name='pre_input_bert') # premise (bert)
bm_input_bt = Input(shape=(768, ), dtype='float32', name='hyp_input_bert') # hypothesis (bert)

# bias_input = Input(shape = (300, ),dtype = 'float32',name='bias_input')
# bias_input_nv = Input(shape = (300, ),dtype = 'float32', name='bias_input_nv')
bias_input_em = Input(shape = (300, ),dtype = 'float32', name='bias_input_em')

top_input_aux = Input(shape=(16, ), dtype='float32', name='pre_aux_features') # lexicon and other features (for premise)
bm_input_aux = Input(shape=(16, ), dtype='float32', name='hyp_aux_features') # lexicon and other features (for hypothesis)

# Embedding layer of LSTM based model
embedding_layer = Embedding(MAX_NUM_WORDS, NUM_EMBEDDING_DIM, weights = [embedding_matrix], trainable = True, name='embedding')
top_embedded_wd = embedding_layer(top_input_wd)
bm_embedded_wd = embedding_layer(bm_input_wd)

# first Bi-LSTM
source_lstm_wd = Bidirectional(LSTM(NUM_LSTM_UNITS, return_sequences=True, recurrent_dropout = 0.3, name="lstm_1"), name="bi_1")
top_source_wd = source_lstm_wd(top_embedded_wd)
bm_source_wd = source_lstm_wd(bm_embedded_wd)

# dense layer
dense_layer_1 = Dense(300, activation='relu', name='dense_1')
top_source_wd_dense = top_source_wd
bm_source_wd_dense = bm_source_wd

# concatenating hidden representations of premise and hypothesis
source_comb_wd = concatenate([top_source_wd_dense, bm_source_wd_dense],axis=-1, name='concat_pre_hyp')

# second Bi-LSTM
shared_lstm_wd = Bidirectional(LSTM(NUM_LSTM_UNITS, return_sequences=True, return_state=True, activation='tanh', recurrent_dropout = 0.3, name="lstm_2"), name="bi_2")
(lstm_ops_wd, forward_h, forward_c, backward_h, backward_c) = shared_lstm_wd(source_comb_wd)

# dense layer
dense_layer_2 = Dense(300, activation='relu', name='dense_2')
lstm_ops_wd_dense = lstm_ops_wd

# attention layer
seq_att, seq_coeffs = AttentionLayer(NUM_EMBEDDING_DIM,return_coefficients=True,name='attention')(lstm_ops_wd_dense)
context_vector_wd = Dropout(0.4,name='dropout')(seq_att) # (None, 300)



# BERT Embeddings
top_embedded_bt = Reshape((1, 768, ), name='reshape_pre_bert')(top_input_bt)
bm_embedded_bt = Reshape((1, 768, ), name='reshape_hyp_bert')(bm_input_bt)

# first Bi-LSTMs
source_lstm_bt = Bidirectional(LSTM(NUM_LSTM_UNITS, return_sequences=True, recurrent_dropout = 0.3, name="lstm_bert_1"), name='bi_bert_1')
top_source_bt = source_lstm_bt(top_embedded_bt)
bm_source_bt = source_lstm_bt(bm_embedded_bt)

# dense layer
dense_layer_3 = Dense(300, activation='relu', name='dense_3')
top_source_bt_dense = dense_layer_3(top_source_bt)
bm_source_bt_dense = dense_layer_3(top_source_bt)

# concatenat premise and hypothesis
source_comb_bt = concatenate([top_source_bt, bm_source_bt],axis=-1,name='concat_pre_hyp_bert')

# second Bi-LSTM
shared_lstm_bt = Bidirectional(LSTM(NUM_LSTM_UNITS, return_sequences=True, return_state=True, activation='tanh', recurrent_dropout = 0.3, name="lstm_bert_2"),name='bi_bert_2')
(lstm_ops_bt, forward_h, forward_c, backward_h, backward_c) = shared_lstm_bt(source_comb_bt)

# dense layer
dense_layer_4 = Dense(300, activation='relu', name='dense_4')
lstm_ops_bt_dense = dense_layer_4(lstm_ops_bt)

# attention layer
seq_att_bt, seq_coeffs_bt = AttentionLayer(NUM_EMBEDDING_DIM,return_coefficients=True,name='attention_bert')(lstm_ops_bt_dense)
context_vector_bt = Dropout(0.4,name='dropout_bert')(seq_att_bt) # (None, 300)



# concatenate new features of premise and hypothesis
comb_aux_features = concatenate([top_input_aux, bm_input_aux], name='concat_pre_hyp_aux')



# concatenation layer

# novelty detection
comb_features_nv = concatenate([context_vector_wd+context_vector_bt+bias_input_nv, \
                                context_vector_wd*context_vector_bt*bias_input_nv, \
                                comb_aux_features],axis=-1, name='concat_nv_features')

# emotion recognition
comb_features_em = concatenate([context_vector_wd+context_vector_bt+bias_input_em, \
                                context_vector_wd*context_vector_bt*bias_input_em, \
                                comb_aux_features],axis=-1, name='concat_em_features')

# fake news detection
comb_features_fnc = concatenate([context_vector_wd+context_vector_bt+bias_input, \
                                 context_vector_wd*context_vector_bt*bias_input, \
                                 comb_aux_features],axis=-1, name='concat_fnc_features')



# task-specific networks
pre_nv = Dense(units=64, activation='tanh', name = 'dense_nv')(comb_features_nv)
pre_em = Dense(units=64, activation='tanh', name = 'dense_em')(comb_features_em)
pre_fnc = Dense(units=64, activation='tanh',name = 'dense_fnc')(comb_features_fnc)

# prediction
dense_nv =  Dense(units=NUM_CLASSES, activation='softmax',name = 'nv')
dense_em =  Dense(units=NUM_CLASSES, activation='softmax',name = 'em')
dense_fnc =  Dense(units=NUM_CLASSES, activation='softmax',name = 'fnc')

# outputs
predictions_nv = dense_nv(pre_nv)
predictions_em = dense_em(pre_em)
predictions_fnc = dense_fnc(pre_fnc)

model_lstm = Model(
    inputs=[top_input_wd, bm_input_wd, top_input_bt, bm_input_bt, bias_input, bias_input_nv, bias_input_em, top_input_aux, bm_input_aux],
    outputs=[predictions_nv, predictions_em, predictions_fnc])

model_lstm.summary()
# Out:
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# /usr/local/lib/python3.10/dist-packages/keras/initializers/initializers.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# WARNING:tensorflow:Layer lstm_bert_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_bert_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_bert_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_bert_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_bert_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_bert_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  pre_input_bert (InputLayer)    [(None, 768)]        0           []
#
#  hyp_input_bert (InputLayer)    [(None, 768)]        0           []
#
#  pre_input (InputLayer)         [(None, 150)]        0           []
#
#  hyp_input (InputLayer)         [(None, 150)]        0           []
#
#  reshape_pre_bert (Reshape)     (None, 1, 768)       0           ['pre_input_bert[0][0]']
#
#  reshape_hyp_bert (Reshape)     (None, 1, 768)       0           ['hyp_input_bert[0][0]']
#
#  embedding (Embedding)          (None, 150, 300)     120000000   ['pre_input[0][0]',
#                                                                   'hyp_input[0][0]']
#
#  bi_bert_1 (Bidirectional)      (None, 1, 300)       1102800     ['reshape_pre_bert[0][0]',
#                                                                   'reshape_hyp_bert[0][0]']
#
#  bi_1 (Bidirectional)           (None, 150, 300)     541200      ['embedding[0][0]',
#                                                                   'embedding[1][0]']
#
#  concat_pre_hyp_bert (Concatena  (None, 1, 600)      0           ['bi_bert_1[0][0]',
#  te)                                                              'bi_bert_1[1][0]']
#
#  concat_pre_hyp (Concatenate)   (None, 150, 600)     0           ['bi_1[0][0]',
#                                                                   'bi_1[1][0]']
#
#  bi_bert_2 (Bidirectional)      [(None, 1, 300),     901200      ['concat_pre_hyp_bert[0][0]']
#                                  (None, 150),
#                                  (None, 150),
#                                  (None, 150),
#                                  (None, 150)]
#
#  bi_2 (Bidirectional)           [(None, 150, 300),   901200      ['concat_pre_hyp[0][0]']
#                                  (None, 150),
#                                  (None, 150),
#                                  (None, 150),
#                                  (None, 150)]
#
#  dense_4 (Dense)                (None, 1, 300)       90300       ['bi_bert_2[0][0]']
#
#  attention (AttentionLayer)     [(None, 300),        90600       ['bi_2[0][0]']
#                                  (None, 150, 1)]
#
#  attention_bert (AttentionLayer  [(None, 300),       90600       ['dense_4[0][0]']
#  )                               (None, 1, 1)]
#
#  dropout (Dropout)              (None, 300)          0           ['attention[0][0]']
#
#  dropout_bert (Dropout)         (None, 300)          0           ['attention_bert[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 300)         0           ['dropout[0][0]',
#  da)                                                              'dropout_bert[0][0]']
#
#  bias_input_nv (InputLayer)     [(None, 300)]        0           []
#
#  tf.math.multiply (TFOpLambda)  (None, 300)          0           ['dropout[0][0]',
#                                                                   'dropout_bert[0][0]']
#
#  pre_aux_features (InputLayer)  [(None, 16)]         0           []
#
#  hyp_aux_features (InputLayer)  [(None, 16)]         0           []
#
#  tf.__operators__.add_2 (TFOpLa  (None, 300)         0           ['dropout[0][0]',
#  mbda)                                                            'dropout_bert[0][0]']
#
#  bias_input_em (InputLayer)     [(None, 300)]        0           []
#
#  tf.math.multiply_2 (TFOpLambda  (None, 300)         0           ['dropout[0][0]',
#  )                                                                'dropout_bert[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 300)         0           ['dropout[0][0]',
#  mbda)                                                            'dropout_bert[0][0]']
#
#  bias_input (InputLayer)        [(None, 300)]        0           []
#
#  tf.math.multiply_4 (TFOpLambda  (None, 300)         0           ['dropout[0][0]',
#  )                                                                'dropout_bert[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 300)         0           ['tf.__operators__.add[0][0]',
#  mbda)                                                            'bias_input_nv[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 300)         0           ['tf.math.multiply[0][0]',
#  )                                                                'bias_input_nv[0][0]']
#
#  concat_pre_hyp_aux (Concatenat  (None, 32)          0           ['pre_aux_features[0][0]',
#  e)                                                               'hyp_aux_features[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 300)         0           ['tf.__operators__.add_2[0][0]',
#  mbda)                                                            'bias_input_em[0][0]']
#
#  tf.math.multiply_3 (TFOpLambda  (None, 300)         0           ['tf.math.multiply_2[0][0]',
#  )                                                                'bias_input_em[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 300)         0           ['tf.__operators__.add_4[0][0]',
#  mbda)                                                            'bias_input[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 300)         0           ['tf.math.multiply_4[0][0]',
#  )                                                                'bias_input[0][0]']
#
#  concat_nv_features (Concatenat  (None, 632)         0           ['tf.__operators__.add_1[0][0]',
#  e)                                                               'tf.math.multiply_1[0][0]',
#                                                                   'concat_pre_hyp_aux[0][0]']
#
#  concat_em_features (Concatenat  (None, 632)         0           ['tf.__operators__.add_3[0][0]',
#  e)                                                               'tf.math.multiply_3[0][0]',
#                                                                   'concat_pre_hyp_aux[0][0]']
#
#  concat_fnc_features (Concatena  (None, 632)         0           ['tf.__operators__.add_5[0][0]',
#  te)                                                              'tf.math.multiply_5[0][0]',
#                                                                   'concat_pre_hyp_aux[0][0]']
#
#  dense_nv (Dense)               (None, 64)           40512       ['concat_nv_features[0][0]']
#
#  dense_em (Dense)               (None, 64)           40512       ['concat_em_features[0][0]']
#
#  dense_fnc (Dense)              (None, 64)           40512       ['concat_fnc_features[0][0]']
#
#  nv (Dense)                     (None, 2)            130         ['dense_nv[0][0]']
#
#  em (Dense)                     (None, 2)            130         ['dense_em[0][0]']
#
#  fnc (Dense)                    (None, 2)            130         ['dense_fnc[0][0]']
#
# ==================================================================================================
# Total params: 123,839,826
# Trainable params: 123,839,826
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# ## Bi-GRUs

# NUM_GRU_UNITS = 150

# top_input_wd = Input( # top-gru (for premise)
#     shape=(MAX_SEQUENCE_LENGTH, ),
#     dtype='int32')
# bm_input_wd = Input( # bottom-gru (for hypothesis)
#     shape=(MAX_SEQUENCE_LENGTH, ),
#     dtype='int32')

# top_input_bt = Input( # top-bert (for premise)
#     shape=(768, ),
#     dtype='float32')
# bm_input_bt = Input( # bottom-bert (for hypothesis)
#     shape=(768, ),
#     dtype='float32')

# bias_input = Input(
#     shape = (300, ),
#     dtype = 'float32')
# bias_input_nv = Input(
#     shape = (300, ),
#     dtype = 'float32')
# bias_input_em = Input(
#     shape = (300, ),
#     dtype = 'float32')

# # Embedding layer of GRU based model
# embedding_layer = Embedding(MAX_NUM_WORDS, NUM_EMBEDDING_DIM, weights = [embedding_matrix], trainable = True)
# top_embedded_wd = embedding_layer(top_input_wd)
# bm_embedded_wd = embedding_layer(bm_input_wd)

# # first Bi-GRU
# source_gru_wd = Bidirectional(GRU(NUM_GRU_UNITS, return_sequences=True, recurrent_dropout = 0.3), name="source_bi_gru")
# top_source_wd = source_gru_wd(top_embedded_wd)
# bm_source_wd = source_gru_wd(bm_embedded_wd) # (None, 100, 300)

# # dense layer
# dense_layer_1 = Dense(300, activation='relu', name='dense_1')
# top_source_wd_dense = dense_layer_1(top_source_wd)
# bm_source_wd_dense = dense_layer_1(bm_source_wd)

# # concatenating hidden representations of premise and hypothesis
# source_comb_wd = concatenate([top_source_wd_dense, bm_source_wd_dense],axis=-1) # (None, 100, 600)

# # second Bi-GRU
# shared_gru_wd = Bidirectional(GRU(NUM_GRU_UNITS, return_sequences=True, return_state=True, activation='tanh', recurrent_dropout = 0.3), name="shared_bi_gru")
# (gru_ops_wd, forward_h, backward_h) = shared_gru_wd(source_comb_wd) # (None, 100, 600)

# # dense layer
# dense_layer_2 = Dense(300, activation='relu', name='dense_2')
# gru_ops_wd_dense = dense_layer_2(gru_ops_wd) # (None, 100, 300)

# # attention layer
# seq_att, seq_coeffs = AttentionLayer(NUM_EMBEDDING_DIM,return_coefficients=True,name='attention_wd')(gru_ops_wd_dense)
# context_vector_wd = Dropout(0.4,name='dropout_wd')(seq_att) # (None, 300)



# # BERT Embeddings
# top_embedded_bt = Reshape((1, 768, ))(top_input_bt)
# bm_embedded_bt = Reshape((1, 768, ))(bm_input_bt)

# # first Bi-GRU
# source_gru_bt = Bidirectional(GRU(NUM_GRU_UNITS, return_sequences=True, recurrent_dropout = 0.3, name="source_bi_gru_bert"))
# top_source_bt = source_gru_bt(top_embedded_bt)
# bm_source_bt = source_gru_bt(bm_embedded_bt)

# # dense layer
# dense_layer_3 = Dense(300, activation='relu', name='dense_3')
# top_source_bt_dense = dense_layer_3(top_source_bt)
# bm_source_bt_dense = dense_layer_3(top_source_bt)

# # concatenat premise and hypothesis
# source_comb_bt = concatenate([top_source_bt, bm_source_bt],axis=-1)

# # second Bi-GRU
# shared_gru_bt = Bidirectional(GRU(NUM_GRU_UNITS, return_sequences=True, return_state=True, activation='tanh', recurrent_dropout = 0.3, name="shared_bi_gru_bert"))
# (gru_ops_bt, forward_h, backward_h) = shared_gru_bt(source_comb_bt)

# # dense layer
# dense_layer_4 = Dense(300, activation='relu', name='dense_4')
# gru_ops_bt_dense = dense_layer_4(gru_ops_bt)

# # attention layer
# seq_att_bt, seq_coeffs_bt = AttentionLayer(NUM_EMBEDDING_DIM,return_coefficients=True,name='attention_bt')(gru_ops_bt_dense)
# context_vector_bt = Dropout(0.4,name='dropout_bt')(seq_att_bt) # (None, 300)



# # concatenation layer

# # novelty detection
# comb_features_nv = concatenate([context_vector_wd+context_vector_bt+bias_input_nv, context_vector_wd*context_vector_bt*bias_input_nv],axis=-1)
# # comb_features_nv = concatenate([context_vector_wd+context_vector_bt+bias_input_nv, context_vector_wd*context_vector_bt*bias_input_em, context_vector_wd*context_vector_bt*bias_input],axis=-1)

# # emotion recognition
# comb_features_em = concatenate([context_vector_wd+context_vector_bt+bias_input_em, context_vector_wd*context_vector_bt*bias_input_em],axis=-1)
# # comb_features_em = concatenate([context_vector_wd+context_vector_bt+bias_input_nv, context_vector_wd*context_vector_bt*bias_input_em, context_vector_wd*context_vector_bt*bias_input],axis=-1)
# # comb_features_em = concatenate([context_vector_wd+context_vector_bt, context_vector_wd-context_vector_bt, context_vector_wd*context_vector_bt],axis=-1)

# # fake news detection
# comb_features_fnc = concatenate([context_vector_wd+context_vector_bt+bias_input, context_vector_wd*context_vector_bt*bias_input],axis=-1)
# # comb_features_fnc = concatenate([context_vector_wd+context_vector_bt+bias_input_nv, context_vector_wd*context_vector_bt*bias_input_em, context_vector_wd*context_vector_bt*bias_input],axis=-1)



# # task-specific networks
# pre_nv = Dense(units=64, activation='tanh', name = 'pre_nv')(comb_features_nv)
# pre_em = Dense(units=64, activation='tanh', name = 'pre_em')(comb_features_em)
# pre_fnc = Dense(units=64, activation='tanh',name = 'pre_fnc')(comb_features_fnc)

# # prediction
# dense_nv =  Dense(units=NUM_CLASSES, activation='softmax',name = 'nv')
# dense_em =  Dense(units=NUM_CLASSES, activation='softmax',name = 'em')
# dense_fnc =  Dense(units=NUM_CLASSES, activation='softmax',name = 'fnc')

# # outputs
# predictions_nv = dense_nv(pre_nv)
# predictions_em = dense_em(pre_em)
# predictions_fnc = dense_fnc(pre_fnc)

# model_gru = Model(
#     inputs=[top_input_wd, bm_input_wd, top_input_bt, bm_input_bt, bias_input, bias_input_nv, bias_input_em],
#     outputs=[predictions_nv, predictions_em, predictions_fnc])

# model_gru.summary()

# %%
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
lr = 0.001
opt = Adam(lr=lr, decay=lr/50)
model_lstm.compile(
    optimizer=opt,
    loss={'nv':'categorical_crossentropy', 'em':'categorical_crossentropy', 'fnc':'categorical_crossentropy'},
    loss_weights={'nv': 0.9, 'em':0.7, 'fnc': 1},
    metrics=['accuracy'])
keras.utils.plot_model(model_lstm, "model_bilstm_fnc.png", show_shapes=True)
checkpointer = ModelCheckpoint(filepath='multitask_fnc_v2.h5', verbose=1, save_best_only=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# MultiTask Model
BATCH_SIZE = 256
NUM_EPOCHS = 50
stop = [EarlyStopping(monitor='val_loss', patience=0.001)]
history = model_lstm.fit(x=[x1_train, x2_train, x1_train_bert, x2_train_bert, train_bias, train_bias_nv, train_bias_em, x1_train_features, x2_train_features],
                    y=[y_train_nv, y_train_em, y_train_fnc],
                    batch_size=BATCH_SIZE,
                    epochs=NUM_EPOCHS,
                    validation_data=(
                      [x1_val, x2_val, x1_val_bert, x2_val_bert, val_bias, val_bias_nv, val_bias_em, x1_val_features, x2_val_features],
                      [y_val_nv, y_val_em, y_val_fnc]
                    ),
                    shuffle=True,
                    callbacks=stop,
          )
# Out:
# Epoch 1/50
# 13/13 [==============================] - 66s 3s/step - loss: 2.2274 - nv_loss: 0.4827 - em_loss: 1.1159 - fnc_loss: 1.0118 - nv_accuracy: 0.8039 - em_accuracy: 0.4998 - fnc_accuracy: 0.5598 - val_loss: 1.4134 - val_nv_loss: 0.4556 - val_em_loss: 0.6550 - val_fnc_loss: 0.5448 - val_nv_accuracy: 0.7790 - val_em_accuracy: 0.6354 - val_fnc_accuracy: 0.8066
# Epoch 2/50
# 13/13 [==============================] - 35s 3s/step - loss: 1.1373 - nv_loss: 0.3485 - em_loss: 0.5430 - fnc_loss: 0.4435 - nv_accuracy: 0.8337 - em_accuracy: 0.6828 - fnc_accuracy: 0.8177 - val_loss: 0.9787 - val_nv_loss: 0.2732 - val_em_loss: 0.4535 - val_fnc_loss: 0.4154 - val_nv_accuracy: 0.8867 - val_em_accuracy: 0.7293 - val_fnc_accuracy: 0.8094
# Epoch 3/50
# 13/13 [==============================] - 36s 3s/step - loss: 0.7992 - nv_loss: 0.1780 - em_loss: 0.3843 - fnc_loss: 0.3700 - nv_accuracy: 0.9453 - em_accuracy: 0.8033 - fnc_accuracy: 0.8235 - val_loss: 0.6437 - val_nv_loss: 0.1135 - val_em_loss: 0.2944 - val_fnc_loss: 0.3354 - val_nv_accuracy: 0.9641 - val_em_accuracy: 0.8812 - val_fnc_accuracy: 0.8287
# Epoch 4/50
# 13/13 [==============================] - 35s 3s/step - loss: 0.5612 - nv_loss: 0.0691 - em_loss: 0.2920 - fnc_loss: 0.2946 - nv_accuracy: 0.9865 - em_accuracy: 0.8632 - fnc_accuracy: 0.8669 - val_loss: 0.4416 - val_nv_loss: 0.0341 - val_em_loss: 0.2582 - val_fnc_loss: 0.2302 - val_nv_accuracy: 0.9917 - val_em_accuracy: 0.8840 - val_fnc_accuracy: 0.8978
# Epoch 5/50
# 13/13 [==============================] - 36s 3s/step - loss: 0.4574 - nv_loss: 0.0282 - em_loss: 0.2648 - fnc_loss: 0.2467 - nv_accuracy: 0.9988 - em_accuracy: 0.8740 - fnc_accuracy: 0.8890 - val_loss: 0.3676 - val_nv_loss: 0.0115 - val_em_loss: 0.2332 - val_fnc_loss: 0.1940 - val_nv_accuracy: 1.0000 - val_em_accuracy: 0.8923 - val_fnc_accuracy: 0.9199
# Epoch 6/50
# 13/13 [==============================] - 35s 3s/step - loss: 0.4051 - nv_loss: 0.0126 - em_loss: 0.2467 - fnc_loss: 0.2211 - nv_accuracy: 1.0000 - em_accuracy: 0.8767 - fnc_accuracy: 0.9078 - val_loss: 0.3549 - val_nv_loss: 0.0063 - val_em_loss: 0.2287 - val_fnc_loss: 0.1891 - val_nv_accuracy: 1.0000 - val_em_accuracy: 0.8895 - val_fnc_accuracy: 0.9254
# Epoch 7/50
# 13/13 [==============================] - 36s 3s/step - loss: 0.3861 - nv_loss: 0.0071 - em_loss: 0.2382 - fnc_loss: 0.2129 - nv_accuracy: 1.0000 - em_accuracy: 0.8853 - fnc_accuracy: 0.9056 - val_loss: 0.3474 - val_nv_loss: 0.0047 - val_em_loss: 0.2308 - val_fnc_loss: 0.1816 - val_nv_accuracy: 1.0000 - val_em_accuracy: 0.8867 - val_fnc_accuracy: 0.9199
# Epoch 8/50
# 13/13 [==============================] - 36s 3s/step - loss: 0.3737 - nv_loss: 0.0052 - em_loss: 0.2363 - fnc_loss: 0.2036 - nv_accuracy: 1.0000 - em_accuracy: 0.8863 - fnc_accuracy: 0.9133 - val_loss: 0.3289 - val_nv_loss: 0.0034 - val_em_loss: 0.2182 - val_fnc_loss: 0.1732 - val_nv_accuracy: 1.0000 - val_em_accuracy: 0.9033 - val_fnc_accuracy: 0.9392
# Epoch 9/50
# 13/13 [==============================] - 36s 3s/step - loss: 0.3708 - nv_loss: 0.0039 - em_loss: 0.2321 - fnc_loss: 0.2049 - nv_accuracy: 1.0000 - em_accuracy: 0.8866 - fnc_accuracy: 0.9099 - val_loss: 0.3152 - val_nv_loss: 0.0023 - val_em_loss: 0.2108 - val_fnc_loss: 0.1656 - val_nv_accuracy: 1.0000 - val_em_accuracy: 0.9006 - val_fnc_accuracy: 0.9337
# Epoch 10/50
# 13/13 [==============================] - 35s 3s/step - loss: 0.3633 - nv_loss: 0.0032 - em_loss: 0.2297 - fnc_loss: 0.1995 - nv_accuracy: 1.0000 - em_accuracy: 0.8844 - fnc_accuracy: 0.9136 - val_loss: 0.3186 - val_nv_loss: 0.0021 - val_em_loss: 0.2194 - val_fnc_loss: 0.1632 - val_nv_accuracy: 1.0000 - val_em_accuracy: 0.8978 - val_fnc_accuracy: 0.9337

# %%
from sklearn import metrics
from sklearn.metrics import classification_report
predictions = model_lstm.predict(
    [X1_test, X2_test, pre_bert_fnc_test, hyp_bert_fnc_test, test_bias, test_bias_nv, test_bias_em, pre_features_fnc_test, hyp_features_fnc_test])
# Out:
# 82/82 [==============================] - 23s 282ms/step

# %%
print(np.stack(predictions).shape)
print(predictions[0].shape)
print(predictions[1].shape)
print(predictions[2].shape)
# Out:
# (3, 2600, 2)
# (2600, 2)
# (2600, 2)
# (2600, 2)

# %%
# Result Labels
res_df = pd.DataFrame()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_history(history):

    # Loss
    fig, ((ax1, ax2, ax3)) = plt.subplots(ncols=3, nrows=1, figsize=(12,4))
    losses = ['fnc_loss','nv_loss','em_loss']
    i = 0
    for ax in [ax1, ax2, ax3]:
      ax.plot(history.history[losses[i]], 'g')
      ax.set_title(losses[i])
      ax.set_xlabel('epochs')
      ax.set_ylabel('loss')
      i += 1

    plt.show()

    # Accuracy
    fig, ((ax1, ax2, ax3)) = plt.subplots(ncols=3, nrows=1, figsize=(12,4))
    losses = ['fnc_accuracy','nv_accuracy','em_accuracy']
    i = 0
    for ax in [ax1, ax2, ax3]:
      ax.plot(history.history[losses[i]], 'b')
      ax.set_title(losses[i])
      ax.set_xlabel('epochs')
      ax.set_ylabel('loss')
      i += 1

    plt.show()

# %%
plot_history(history)

# %%
import matplotlib.pyplot as plt
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        title='Normalized confusion matrix'
    else:
        title='Confusion matrix'

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
y_pred = [idx for idx in np.argmax(predictions[2], axis=1)]
res_df['Fake_News_Labels'] = y_pred
#print(y_pred)
print('FNC Accuracy is')
print(metrics.accuracy_score(Y_fnc_test, y_pred)*100)
print(classification_report(Y_fnc_test, y_pred, target_names = ['agree', 'disagree']))
# Out:
# FNC Accuracy is
# 81.76923076923077
#               precision    recall  f1-score   support
#
#        agree       0.82      0.96      0.89      1903
#     disagree       0.80      0.43      0.56       697
#
#     accuracy                           0.82      2600
#    macro avg       0.81      0.69      0.72      2600
# weighted avg       0.81      0.82      0.80      2600

# %%
from sklearn.metrics import confusion_matrix
cnf_matrix = confusion_matrix(Y_fnc_test,y_pred)
print(cnf_matrix)
plot_confusion_matrix(cnf_matrix,classes=le.inverse_transform(np.arange(2)))
# Out:
# [[1827   76]
#  [ 398  299]]

# %%
y_pred = [idx for idx in np.argmax(predictions[1], axis=1)]
res_df['Emotion_Labels'] = y_pred
print('Emotion Accuracy is')
print(metrics.accuracy_score(Y_em_test, y_pred)*100)
print(classification_report(Y_em_test, y_pred, target_names = ['agree', 'disagree']))
# Out:
# Emotion Accuracy is
# 50.88461538461539
#               precision    recall  f1-score   support
#
#        agree       0.57      0.52      0.54      1468
#     disagree       0.44      0.50      0.47      1132
#
#     accuracy                           0.51      2600
#    macro avg       0.51      0.51      0.51      2600
# weighted avg       0.52      0.51      0.51      2600

# %%
cnf_matrix = confusion_matrix(Y_em_test,y_pred)
print(cnf_matrix)
plot_confusion_matrix(cnf_matrix,classes=le2.inverse_transform(np.arange(2)))
# Out:
# [[762 706]
#  [571 561]]

# %%
y_pred = [idx for idx in np.argmax(predictions[0], axis=1)]
res_df['Novelty_Labels'] = y_pred
print('NV Accuracy is')
print(metrics.accuracy_score(Y_nv_test, y_pred)*100)
print(classification_report(Y_nv_test, y_pred, target_names = ['novel', 'duplicate']))
# Out:
# NV Accuracy is
# 100.0
#               precision    recall  f1-score   support
#
#        novel       1.00      1.00      1.00       386
#    duplicate       1.00      1.00      1.00      2214
#
#     accuracy                           1.00      2600
#    macro avg       1.00      1.00      1.00      2600
# weighted avg       1.00      1.00      1.00      2600

# %%
cnf_matrix = confusion_matrix(Y_nv_test,y_pred)
print(cnf_matrix)
plot_confusion_matrix(cnf_matrix,classes=['novel','duplicate'])
# Out:
# [[ 386    0]
#  [   0 2214]]

# %%
# Saving the labels
res_df.to_csv("FNC_Multitask_results.csv", index = False)

# %%
## Multitask model for only disagreement detection and emotion recognition

top_input_wd = Input( # top-lstm (for premise)
    shape=(MAX_SEQUENCE_LENGTH, ),
    dtype='int32')
bm_input_wd = Input( # bottom-lstm (for hypothesis)
    shape=(MAX_SEQUENCE_LENGTH, ),
    dtype='int32')

top_input_bt = Input( # top-bert (for premise)
    shape=(768, ),
    dtype='float32')
bm_input_bt = Input( # bottom-bert (for hypothesis)
    shape=(768, ),
    dtype='float32')

# bias_input = Input(
#     shape = (300, ),
#     dtype = 'float32')
bias_input_em = Input(
    shape = (300, ),
    dtype = 'float32')

top_input_aux = Input( # lexicon and other features (for premise)
    shape=(16, ),
    dtype='float32')
bm_input_aux = Input( # lexicon and other features (for hypothesis)
    shape=(16, ),
    dtype='float32')

# Embedding layer of LSTM based model
embedding_layer = Embedding(MAX_NUM_WORDS, NUM_EMBEDDING_DIM, weights = [embedding_matrix], trainable = True)
top_embedded_wd = embedding_layer(top_input_wd)
bm_embedded_wd = embedding_layer(bm_input_wd)

# first Bi-LSTM
source_lstm_wd = Bidirectional(LSTM(NUM_LSTM_UNITS, return_sequences=True, recurrent_dropout = 0.3), name="source_bi_lstm")
top_source_wd = source_lstm_wd(top_embedded_wd)
bm_source_wd = source_lstm_wd(bm_embedded_wd) # (None, 100, 300)

# dense layer
dense_layer_1 = Dense(300, activation='relu', name='dense_1')
top_source_wd_dense = dense_layer_1(top_source_wd)
bm_source_wd_dense = dense_layer_1(bm_source_wd)

# concatenating hidden representations of premise and hypothesis
source_comb_wd = concatenate([top_source_wd_dense, bm_source_wd_dense],axis=-1) # (None, 100, 600)

# second Bi-LSTM
shared_lstm_wd = Bidirectional(LSTM(NUM_LSTM_UNITS, return_sequences=True, return_state=True, activation='tanh', recurrent_dropout = 0.3), name="shared_bi_lstm")
(lstm_ops_wd, forward_h, forward_c, backward_h, backward_c) = shared_lstm_wd(source_comb_wd) # (None, 100, 600)

# dense layer
dense_layer_2 = Dense(300, activation='relu', name='dense_2')
lstm_ops_wd_dense = dense_layer_2(lstm_ops_wd) # (None, 100, 300)

# attention layer
seq_att, seq_coeffs = AttentionLayer(NUM_EMBEDDING_DIM,return_coefficients=True,name='attention_wd')(lstm_ops_wd_dense)
context_vector_wd = Dropout(0.4,name='dropout_wd')(seq_att) # (None, 300)



# BERT Embeddings
top_embedded_bt = Reshape((1, 768, ))(top_input_bt)
bm_embedded_bt = Reshape((1, 768, ))(bm_input_bt)

# first Bi-LSTMs
source_lstm_bt = Bidirectional(LSTM(NUM_LSTM_UNITS, return_sequences=True, recurrent_dropout = 0.3, name="source_lstm_bert"))
top_source_bt = source_lstm_bt(top_embedded_bt)
bm_source_bt = source_lstm_bt(bm_embedded_bt)

# dense layer
dense_layer_3 = Dense(300, activation='relu', name='dense_3')
top_source_bt_dense = dense_layer_3(top_source_bt)
bm_source_bt_dense = dense_layer_3(top_source_bt)

# concatenat premise and hypothesis
source_comb_bt = concatenate([top_source_bt, bm_source_bt],axis=-1)

# second Bi-LSTM
shared_lstm_bt = Bidirectional(LSTM(NUM_LSTM_UNITS, return_sequences=True, return_state=True, activation='tanh', recurrent_dropout = 0.3, name="shared_lstm_bert"))
(lstm_ops_bt, forward_h, forward_c, backward_h, backward_c) = shared_lstm_bt(source_comb_bt)

# dense layer
dense_layer_4 = Dense(300, activation='relu', name='dense_4')
lstm_ops_bt_dense = dense_layer_4(lstm_ops_bt)

# attention layer
seq_att_bt, seq_coeffs_bt = AttentionLayer(NUM_EMBEDDING_DIM,return_coefficients=True,name='attention_bt')(lstm_ops_bt_dense)
context_vector_bt = Dropout(0.4,name='dropout_bt')(seq_att_bt) # (None, 300)



# concatenate new features of premise and hypothesis
comb_aux_features = concatenate([top_input_aux, bm_input_aux])



# concatenation layer

# emotion recognition
comb_features_em = concatenate([context_vector_wd+context_vector_bt, \
                                context_vector_wd*context_vector_bt, \
                                comb_aux_features],axis=-1)

# disagreement detection
comb_features_fnc = concatenate([context_vector_wd+context_vector_bt+bias_input_em, \
                                 context_vector_wd*context_vector_bt*bias_input_em, \
                                 comb_aux_features],axis=-1)
# comb_features_fnc = concatenate([context_vector_wd+context_vector_bt, context_vector_wd*context_vector_bt],axis=-1)

# task-specific networks
pre_em = Dense(units=64, activation='tanh', name = 'pre_em')(comb_features_em)
pre_fnc = Dense(units=64, activation='tanh',name = 'pre_fnc')(comb_features_fnc)

# prediction
dense_em =  Dense(units=NUM_CLASSES, activation='softmax',name = 'em')
dense_fnc =  Dense(units=NUM_CLASSES, activation='softmax',name = 'fnc')

# outputs
predictions_em = dense_em(pre_em)
predictions_fnc = dense_fnc(pre_fnc)

model_dg_em = Model(
    inputs=[top_input_wd, bm_input_wd, top_input_bt, bm_input_bt, bias_input_em, top_input_aux, bm_input_aux],
    outputs=[predictions_em, predictions_fnc])

model_dg_em.summary()
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# /usr/local/lib/python3.10/dist-packages/keras/initializers/initializers.py:120: UserWarning: The initializer GlorotUniform is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# WARNING:tensorflow:Layer source_lstm_bert will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer source_lstm_bert will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer source_lstm_bert will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer shared_lstm_bert will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer shared_lstm_bert will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer shared_lstm_bert will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 150)]        0           []
#
#  input_2 (InputLayer)           [(None, 150)]        0           []
#
#  embedding (Embedding)          (None, 150, 300)     120000000   ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  input_3 (InputLayer)           [(None, 768)]        0           []
#
#  input_4 (InputLayer)           [(None, 768)]        0           []
#
#  source_bi_lstm (Bidirectional)  (None, 150, 300)    541200      ['embedding[0][0]',
#                                                                   'embedding[1][0]']
#
#  reshape (Reshape)              (None, 1, 768)       0           ['input_3[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 768)       0           ['input_4[0][0]']
#
#  dense_1 (Dense)                (None, 150, 300)     90300       ['source_bi_lstm[0][0]',
#                                                                   'source_bi_lstm[1][0]']
#
#  bidirectional (Bidirectional)  (None, 1, 300)       1102800     ['reshape[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  concatenate (Concatenate)      (None, 150, 600)     0           ['dense_1[0][0]',
#                                                                   'dense_1[1][0]']
#
#  concatenate_1 (Concatenate)    (None, 1, 600)       0           ['bidirectional[0][0]',
#                                                                   'bidirectional[1][0]']
#
#  shared_bi_lstm (Bidirectional)  [(None, 150, 300),  901200      ['concatenate[0][0]']
#                                  (None, 150),
#                                  (None, 150),
#                                  (None, 150),
#                                  (None, 150)]
#
#  bidirectional_1 (Bidirectional  [(None, 1, 300),    901200      ['concatenate_1[0][0]']
#  )                               (None, 150),
#                                  (None, 150),
#                                  (None, 150),
#                                  (None, 150)]
#
#  dense_2 (Dense)                (None, 150, 300)     90300       ['shared_bi_lstm[0][0]']
#
#  dense_4 (Dense)                (None, 1, 300)       90300       ['bidirectional_1[0][0]']
#
#  attention_wd (AttentionLayer)  [(None, 300),        90600       ['dense_2[0][0]']
#                                  (None, 150, 1)]
#
#  attention_bt (AttentionLayer)  [(None, 300),        90600       ['dense_4[0][0]']
#                                  (None, 1, 1)]
#
#  dropout_wd (Dropout)           (None, 300)          0           ['attention_wd[0][0]']
#
#  dropout_bt (Dropout)           (None, 300)          0           ['attention_bt[0][0]']
#
#  input_6 (InputLayer)           [(None, 16)]         0           []
#
#  input_7 (InputLayer)           [(None, 16)]         0           []
#
#  tf.__operators__.add_1 (TFOpLa  (None, 300)         0           ['dropout_wd[0][0]',
#  mbda)                                                            'dropout_bt[0][0]']
#
#  input_5 (InputLayer)           [(None, 300)]        0           []
#
#  tf.math.multiply_1 (TFOpLambda  (None, 300)         0           ['dropout_wd[0][0]',
#  )                                                                'dropout_bt[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 300)         0           ['dropout_wd[0][0]',
#  da)                                                              'dropout_bt[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 300)          0           ['dropout_wd[0][0]',
#                                                                   'dropout_bt[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 32)           0           ['input_6[0][0]',
#                                                                   'input_7[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 300)         0           ['tf.__operators__.add_1[0][0]',
#  mbda)                                                            'input_5[0][0]']
#
#  tf.math.multiply_2 (TFOpLambda  (None, 300)         0           ['tf.math.multiply_1[0][0]',
#  )                                                                'input_5[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 632)          0           ['tf.__operators__.add[0][0]',
#                                                                   'tf.math.multiply[0][0]',
#                                                                   'concatenate_2[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 632)          0           ['tf.__operators__.add_2[0][0]',
#                                                                   'tf.math.multiply_2[0][0]',
#                                                                   'concatenate_2[0][0]']
#
#  pre_em (Dense)                 (None, 64)           40512       ['concatenate_3[0][0]']
#
#  pre_fnc (Dense)                (None, 64)           40512       ['concatenate_4[0][0]']
#
#  em (Dense)                     (None, 2)            130         ['pre_em[0][0]']
#
#  fnc (Dense)                    (None, 2)            130         ['pre_fnc[0][0]']
#
# ==================================================================================================
# Total params: 123,979,784
# Trainable params: 123,979,784
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
lr = 0.001
opt = Adam(lr=lr, decay=lr/50)
model_dg_em.compile(
    optimizer=opt,
    loss={'em':'categorical_crossentropy', 'fnc':'categorical_crossentropy'},
    loss_weights={'em':1, 'fnc':1},
    metrics=['accuracy'])
checkpointer = ModelCheckpoint(filepath='multitask_dg_em_fnc.h5', verbose=1, save_best_only=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
# Disagreement detection and emotion recognition
BATCH_SIZE = 256
NUM_EPOCHS = 50
stop = [EarlyStopping(monitor='val_loss', patience=0.001)]
history = model_dg_em.fit(x=[x1_train, x2_train, x1_train_bert, x2_train_bert, train_bias_em, x1_train_features, x2_train_features],
                    y=[y_train_em, y_train_fnc],
                    batch_size=BATCH_SIZE,
                    epochs=NUM_EPOCHS,
                    validation_data=(
                      [x1_val, x2_val, x1_val_bert, x2_val_bert, val_bias_em, x1_val_features, x2_val_features],
                      [y_val_em, y_val_fnc]
                    ),
                    shuffle=True,
                    callbacks=stop,
          )
# Out:
# Epoch 1/50
# 13/13 [==============================] - 65s 3s/step - loss: 1.3163 - em_loss: 0.7202 - fnc_loss: 0.5961 - em_accuracy: 0.6191 - fnc_accuracy: 0.6984 - val_loss: 1.1354 - val_em_loss: 0.6555 - val_fnc_loss: 0.4799 - val_em_accuracy: 0.5691 - val_fnc_accuracy: 0.8066
# Epoch 2/50
# 13/13 [==============================] - 35s 3s/step - loss: 1.1147 - em_loss: 0.6545 - fnc_loss: 0.4602 - em_accuracy: 0.6431 - fnc_accuracy: 0.8137 - val_loss: 1.1138 - val_em_loss: 0.6663 - val_fnc_loss: 0.4474 - val_em_accuracy: 0.6133 - val_fnc_accuracy: 0.8066
# Epoch 3/50
# 13/13 [==============================] - 34s 3s/step - loss: 1.0553 - em_loss: 0.6411 - fnc_loss: 0.4142 - em_accuracy: 0.6502 - fnc_accuracy: 0.8174 - val_loss: 1.0363 - val_em_loss: 0.6449 - val_fnc_loss: 0.3913 - val_em_accuracy: 0.6326 - val_fnc_accuracy: 0.8094
# Epoch 4/50
# 13/13 [==============================] - 34s 3s/step - loss: 0.9878 - em_loss: 0.6395 - fnc_loss: 0.3484 - em_accuracy: 0.6542 - fnc_accuracy: 0.8297 - val_loss: 0.9475 - val_em_loss: 0.6384 - val_fnc_loss: 0.3091 - val_em_accuracy: 0.6381 - val_fnc_accuracy: 0.8619
# Epoch 5/50
# 13/13 [==============================] - 34s 3s/step - loss: 0.9271 - em_loss: 0.6378 - fnc_loss: 0.2892 - em_accuracy: 0.6511 - fnc_accuracy: 0.8687 - val_loss: 0.8771 - val_em_loss: 0.6262 - val_fnc_loss: 0.2509 - val_em_accuracy: 0.6243 - val_fnc_accuracy: 0.8978
# Epoch 6/50
# 13/13 [==============================] - 34s 3s/step - loss: 0.8962 - em_loss: 0.6343 - fnc_loss: 0.2619 - em_accuracy: 0.6483 - fnc_accuracy: 0.8780 - val_loss: 0.8395 - val_em_loss: 0.6050 - val_fnc_loss: 0.2345 - val_em_accuracy: 0.6409 - val_fnc_accuracy: 0.8978
# Epoch 7/50
# 13/13 [==============================] - 34s 3s/step - loss: 0.8328 - em_loss: 0.6012 - fnc_loss: 0.2316 - em_accuracy: 0.6769 - fnc_accuracy: 0.8939 - val_loss: 0.8328 - val_em_loss: 0.6068 - val_fnc_loss: 0.2260 - val_em_accuracy: 0.6768 - val_fnc_accuracy: 0.9061
# Epoch 8/50
# 13/13 [==============================] - 34s 3s/step - loss: 0.7914 - em_loss: 0.5753 - fnc_loss: 0.2161 - em_accuracy: 0.7077 - fnc_accuracy: 0.8890 - val_loss: 0.6929 - val_em_loss: 0.5220 - val_fnc_loss: 0.1709 - val_em_accuracy: 0.7680 - val_fnc_accuracy: 0.9171
# Epoch 9/50
# 13/13 [==============================] - 34s 3s/step - loss: 0.7165 - em_loss: 0.5331 - fnc_loss: 0.1834 - em_accuracy: 0.7571 - fnc_accuracy: 0.9142 - val_loss: 0.6240 - val_em_loss: 0.4767 - val_fnc_loss: 0.1473 - val_em_accuracy: 0.7956 - val_fnc_accuracy: 0.9448
# Epoch 10/50
# 13/13 [==============================] - 33s 3s/step - loss: 0.6878 - em_loss: 0.5154 - fnc_loss: 0.1724 - em_accuracy: 0.7611 - fnc_accuracy: 0.9244 - val_loss: 0.6607 - val_em_loss: 0.4938 - val_fnc_loss: 0.1669 - val_em_accuracy: 0.7762 - val_fnc_accuracy: 0.9171

# %%
from sklearn import metrics
from sklearn.metrics import classification_report
predictions = model_dg_em.predict(
    [X1_test, X2_test, pre_bert_fnc_test, hyp_bert_fnc_test, test_bias_em, pre_features_fnc_test, hyp_features_fnc_test])
# Out:
# 82/82 [==============================] - 24s 265ms/step

# %%
print(np.stack(predictions).shape)
print(predictions[0].shape)
print(predictions[1].shape)
# Out:
# (2, 2600, 2)
# (2600, 2)
# (2600, 2)

# %%
res_df_2 = pd.DataFrame()

# %%
y_pred = [idx for idx in np.argmax(predictions[1], axis=1)]
res_df_2['Fake_News_Labels'] = y_pred
print('FNC Accuracy is')
print(metrics.accuracy_score(Y_fnc_test, y_pred)*100)
print(classification_report(Y_fnc_test, y_pred, target_names = ['agree', 'disagree']))
# Out:
# FNC Accuracy is
# 82.57692307692308
#               precision    recall  f1-score   support
#
#        agree       0.84      0.94      0.89      1903
#     disagree       0.75      0.52      0.62       697
#
#     accuracy                           0.83      2600
#    macro avg       0.80      0.73      0.75      2600
# weighted avg       0.82      0.83      0.81      2600

# %%
y_pred = [idx for idx in np.argmax(predictions[0], axis=1)]
res_df_2['Emotion_Labels'] = y_pred
print('Emotion Accuracy is')
print(metrics.accuracy_score(Y_em_test, y_pred)*100)
print(classification_report(Y_em_test, y_pred, target_names = ['agree', 'disagree']))
# Out:
# Emotion Accuracy is
# 60.92307692307693
#               precision    recall  f1-score   support
#
#        agree       0.64      0.72      0.68      1468
#     disagree       0.56      0.46      0.51      1132
#
#     accuracy                           0.61      2600
#    macro avg       0.60      0.59      0.59      2600
# weighted avg       0.60      0.61      0.60      2600
